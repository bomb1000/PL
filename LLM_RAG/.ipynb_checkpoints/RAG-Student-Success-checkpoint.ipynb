# %% [markdown]
# # 後測用LLM
# * 請逐一執行每一個區塊直至最後，將會看到聊天視窗
# * 目前執行格執行完畢才可以往下一個執行格

# %%
! pip install -q -U pypdf faiss-cpu
! pip install -q -U InstructorEmbedding
! pip install huggingface_hub -q
! pip install gradio -q
! pip install langchain==0.1.2 
! pip install sentence_transformers==2.2.2
# Out:
# Requirement already satisfied: langchain==0.1.2 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (0.1.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.14 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (0.0.18)
# Requirement already satisfied: langchain-core<0.2,>=0.1.14 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (0.1.19)
# Requirement already satisfied: langsmith<0.0.84,>=0.0.83 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (0.0.83)
# Requirement already satisfied: numpy<2,>=1 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (1.24.3)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (2.6.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (2.28.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain==0.1.2) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.2) (3.21.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.2) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.2) (2.4)
# Requirement already satisfied: anyio<5,>=3 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain-core<0.2,>=0.1.14->langchain==0.1.2) (3.5.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from langchain-core<0.2,>=0.1.14->langchain==0.1.2) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from pydantic<3,>=1->langchain==0.1.2) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from pydantic<3,>=1->langchain==0.1.2) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from pydantic<3,>=1->langchain==0.1.2) (4.10.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from requests<3,>=2->langchain==0.1.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from requests<3,>=2->langchain==0.1.2) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from requests<3,>=2->langchain==0.1.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from requests<3,>=2->langchain==0.1.2) (2023.5.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.2) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.14->langchain==0.1.2) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.2) (1.0.0)
# Collecting sentence_transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ---------------------------------------- 0.0/86.0 kB ? eta -:--:--
#      -------------- ------------------------- 30.7/86.0 kB 1.4 MB/s eta 0:00:01
#      -------------- ------------------------- 30.7/86.0 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 86.0/86.0 kB 605.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting transformers<5.0.0,>=4.6.0 (from sentence_transformers==2.2.2)
#   Downloading transformers-4.38.1-py3-none-any.whl.metadata (131 kB)
#      ---------------------------------------- 0.0/131.1 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/131.1 kB ? eta -:--:--
#      --------------------- ----------------- 71.7/131.1 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 131.1/131.1 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from sentence_transformers==2.2.2) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from sentence_transformers==2.2.2) (2.0.1+cu118)
# Requirement already satisfied: torchvision in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from sentence_transformers==2.2.2) (0.15.2+cu118)
# Requirement already satisfied: numpy in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from sentence_transformers==2.2.2) (1.24.3)
# Requirement already satisfied: scikit-learn in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from sentence_transformers==2.2.2) (1.2.2)
# Requirement already satisfied: scipy in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from sentence_transformers==2.2.2) (1.10.1)
# Collecting nltk (from sentence_transformers==2.2.2)
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting sentencepiece (from sentence_transformers==2.2.2)
#   Downloading sentencepiece-0.2.0-cp38-cp38-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from sentence_transformers==2.2.2) (0.21.2)
# Requirement already satisfied: filelock in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (2024.2.0)
# Requirement already satisfied: requests in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (2.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (23.2)
# Requirement already satisfied: sympy in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from torch>=1.6.0->sentence_transformers==2.2.2) (1.11.1)
# Requirement already satisfied: networkx in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from torch>=1.6.0->sentence_transformers==2.2.2) (3.0)
# Requirement already satisfied: jinja2 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from torch>=1.6.0->sentence_transformers==2.2.2) (3.1.2)
# Requirement already satisfied: colorama in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from tqdm->sentence_transformers==2.2.2) (0.4.6)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2)
#   Downloading regex-2023.12.25-cp38-cp38-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB 2.1 MB/s eta 0:00:00
# Collecting tokenizers<0.19,>=0.14 (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2)
#   Downloading tokenizers-0.15.2-cp38-none-win_amd64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2)
#   Downloading safetensors-0.4.2-cp38-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: click in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from nltk->sentence_transformers==2.2.2) (8.1.7)
# Requirement already satisfied: joblib in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from nltk->sentence_transformers==2.2.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from scikit-learn->sentence_transformers==2.2.2) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from torchvision->sentence_transformers==2.2.2) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from jinja2->torch>=1.6.0->sentence_transformers==2.2.2) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\micha\anaconda3\envs\webcrawling\lib\site-packages (from sympy->torch>=1.6.0->sentence_transformers==2.2.2) (1.2.1)
# Downloading transformers-4.38.1-py3-none-any.whl (8.5 MB)
#    ---------------------------------------- 0.0/8.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125960 sha256=f12372199a15d91e2de2c183d07eecf1f84a6345c17cad0eb283a52e7a92247d
#   Stored in directory: c:\users\micha\appdata\local\pip\cache\wheels\5e\6f\8c\d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
# Successfully built sentence_transformers
# Installing collected packages: sentencepiece, safetensors, regex, nltk, tokenizers, transformers, sentence_transformers
# Successfully installed nltk-3.8.1 regex-2023.12.25 safetensors-0.4.2 sentence_transformers-2.2.2 sentencepiece-0.2.0 tokenizers-0.15.2 transformers-4.38.1

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import glob
import textwrap
import time

# %%
import langchain

# %%
from langchain.document_loaders import PyPDFLoader

# %%
from langchain.document_loaders import DirectoryLoader

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
from langchain import PromptTemplate, LLMChain

# %%
from langchain.llms import HuggingFacePipeline

# %%
from InstructorEmbedding import INSTRUCTOR

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

# %%
from langchain.chains import RetrievalQA

# %%
import torch

# %%
from langchain.vectorstores import FAISS

# %%
class CFG:
    model_name = 'mistralai/Mistral-7B-Instruct-v0.1'
    temperature = 0.5
    top_p = 0.95
    repetition_penalty = 1.15
    do_sample = True
    max_new_tokens = 400
    num_return_sequences=1

    split_chunk_size = 800
    split_overlap = 0
    
    embeddings_model_repo = 'sentence-transformers/all-MiniLM-L6-v2'

    k = 3
    
    PDFs_path = './Python/'
    Embeddings_path =  './faiss_index_py'

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
from langchain.llms import HuggingFaceHub

llm = HuggingFaceHub(
    repo_id = CFG.model_name,
    model_kwargs={
        "max_new_tokens": CFG.max_new_tokens,
        "temperature": CFG.temperature,
        "top_p": CFG.top_p,
        "repetition_penalty": CFG.repetition_penalty,
        "do_sample": CFG.do_sample,
        "num_return_sequences": CFG.num_return_sequences
    }
)

# %%
loader = DirectoryLoader(
    CFG.PDFs_path,
    glob="./*.pdf",
    loader_cls=PyPDFLoader,
    show_progress=True,
    use_multithreading=True
)

documents = loader.load()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.71s/it]

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = CFG.split_chunk_size,
    chunk_overlap = CFG.split_overlap
)

texts = text_splitter.split_documents(documents)

# %%
embeddings = HuggingFaceInstructEmbeddings(
    model_name = CFG.embeddings_model_repo,
    model_kwargs = {"device": "cpu"}
)

vectordb = FAISS.from_documents(
    documents = texts, 
    embedding = embeddings
)

vectordb.save_local("faiss_index_py")
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
embeddings = HuggingFaceInstructEmbeddings(
    model_name = CFG.embeddings_model_repo,
    model_kwargs = {"device": "cpu"}
)

vectordb = FAISS.load_local(
    CFG.Embeddings_path,
    embeddings
)

# %%
prompt_template = """
<s>[INST] 
Don't try to make up an answer, if you don't know just say that you don't know.
Answer in the same language the question was asked.
Answer the code in python language.
Use only the following pieces of context to answer the question at the end.

{context}

Question: {question}
Answer:[/INST]"""

PROMPT = PromptTemplate(
    template = prompt_template, 
    input_variables = ["question", "context"]
)

# %%
llm_chain = LLMChain(prompt=PROMPT, llm=llm)

# %%
retriever = vectordb.as_retriever(search_kwargs = {"k": CFG.k, "search_type" : "similarity"})

qa_chain = RetrievalQA.from_chain_type(
    llm = llm,
    chain_type = "stuff",
    retriever = retriever, 
    chain_type_kwargs = {"prompt": PROMPT},
    return_source_documents = True,
    verbose = False
)

# %%
def wrap_text_preserve_newlines(text, width=700):
    lines = text.split('\n')

    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]

    wrapped_text = '\n'.join(wrapped_lines)

    return wrapped_text


def process_llm_response(llm_response):
    ans = wrap_text_preserve_newlines(llm_response['result'])
    
    sources_used = ' \n'.join(
        [
            source.metadata['source'].split('/')[-1][:-4] + ' - page: ' + str(source.metadata['page'])
            for source in llm_response['source_documents']
        ]
    )
    
    ans = ans + '\n\nSources: \n' + sources_used
    return ans

# %%
def llm_ans(query):
    start = time.time()
    llm_response = qa_chain(query)
    ans = process_llm_response(llm_response)
    end = time.time()

    time_elapsed = int(round(end - start, 0))
    time_elapsed_str = f'\n\nTime elapsed: {time_elapsed} s'
    return ans.strip() + time_elapsed_str

# %%
def extract_text_after_inst(input_string):
    marker_index = input_string.find("[/INST]")
    
    if marker_index != -1:
        return input_string[marker_index + len("[/INST]"):].strip()
    else:
        return ""

# %%
import gradio as gr

def predict(message, history):
    output = str(llm_ans(message))
    output = extract_text_after_inst(output)
    return output


with gr.Blocks() as demo:
    gr.ChatInterface(
        fn=predict,
        title = f' Open-Source LLM ({CFG.model_name}) for Python Question Answering'
    )
demo.launch()
