# %%
import module

# %%
# Example of using the class
scraper = module.MovieReviewScraper()
scraper.fetch_review_links()
scraper.scrape_review_contents()
df_reviews = scraper.process_reviews()
display(df_reviews.head())
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\micha\AppData\Local\Temp\jieba.cache
# Loading model cost 0.613 seconds.
# Prefix dict has been built successfully.
#                               url  \
# 0  https://news.agentm.tw/277749/
# 1  https://news.agentm.tw/277359/
# 2  https://news.agentm.tw/277642/
# 3  https://news.agentm.tw/277429/
# 4  https://news.agentm.tw/277536/
#
#                                              content     movie_name  \
# 0  【影評】《活個精彩》：一段意想不到的友情篇章，看凱文哈特展現內斂的一面 – 電影神搜   資...           活個精彩
# 1  日本黑道電影《冰室蓮司：日本統一 台灣篇》: 黑幫火拼跨海爭權，正面碰撞沖繩與台灣最敏感神經...  冰室蓮司：日本統一 台灣篇
# 2  【開箱】《雙面女弒親案》：超越現實的雙面人生 – 電影神搜   資訊集團介紹團隊介紹聯絡我們...         雙面女弒親案
# 3  【影評】《非紳士特攻隊》: 一頓反類型公式的豐富大餐，有三種不同的風味，與歡樂至上的滿足 –...         非紳士特攻隊
# 4  【影評】《皇室醜聞夜》：敘事節奏偏緩慢，但至少群戲演技撐起戲劇張力 – 電影神搜   資訊集...          皇室醜聞夜
#
#                                       keywords
# 0    [活個, 電影, 哈特, 凱文, 精彩, 電影神, 影評, --, 介紹, 我們]
# 1   [冰室, 統一, 電影, 台灣, 日本, 台灣篇, 本片, 蓮司, 電影神, 影評]
# 2  [雙面, 親案, 珍妮佛, 電影神, 電影, 影評, --, 紀錄片, 我們, 條款]
# 3   [電影, 士特, 非紳, 攻隊, 蓋瑞奇, 他們, 影評, 納粹, 電影神, 任務]
# 4  [醜聞夜, 皇室, 影評, 電影神, 新聞, 電影, --, 安德魯, 真實, 條款]

# %%
# 假設df是包含movie_name和keywords的DataFrame
network = module.MovieReviewNetwork()
network.add_reviews_to_graph(df_reviews)
network.draw_graph()
# Out:
# C:\Users\micha\anaconda3\envs\webcrawling\lib\site-packages\networkx\drawing\nx_pylab.py:433: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(

# %%
display(df_reviews.head())
# Out:
#                               url  \
# 0  https://news.agentm.tw/277749/
# 1  https://news.agentm.tw/277359/
# 2  https://news.agentm.tw/277642/
# 3  https://news.agentm.tw/277429/
# 4  https://news.agentm.tw/277536/
#
#                                              content     movie_name  \
# 0  【影評】《活個精彩》：一段意想不到的友情篇章，看凱文哈特展現內斂的一面 – 電影神搜   資...           活個精彩
# 1  日本黑道電影《冰室蓮司：日本統一 台灣篇》: 黑幫火拼跨海爭權，正面碰撞沖繩與台灣最敏感神經...  冰室蓮司：日本統一 台灣篇
# 2  【開箱】《雙面女弒親案》：超越現實的雙面人生 – 電影神搜   資訊集團介紹團隊介紹聯絡我們...         雙面女弒親案
# 3  【影評】《非紳士特攻隊》: 一頓反類型公式的豐富大餐，有三種不同的風味，與歡樂至上的滿足 –...         非紳士特攻隊
# 4  【影評】《皇室醜聞夜》：敘事節奏偏緩慢，但至少群戲演技撐起戲劇張力 – 電影神搜   資訊集...          皇室醜聞夜
#
#                                       keywords
# 0    [活個, 電影, 哈特, 凱文, 精彩, 電影神, 影評, --, 介紹, 我們]
# 1   [冰室, 統一, 電影, 台灣, 日本, 台灣篇, 本片, 蓮司, 電影神, 影評]
# 2  [雙面, 親案, 珍妮佛, 電影神, 電影, 影評, --, 紀錄片, 我們, 條款]
# 3   [電影, 士特, 非紳, 攻隊, 蓋瑞奇, 他們, 影評, 納粹, 電影神, 任務]
# 4  [醜聞夜, 皇室, 影評, 電影神, 新聞, 電影, --, 安德魯, 真實, 條款]
